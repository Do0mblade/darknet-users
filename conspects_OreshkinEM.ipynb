# %% [markdown]
# #Настройка Git
# *   настроим ник и email
# *   получить токен github

# %%
# !git config --global user.name "OreshkinEM"
# !git config --global user.email "oreshkine04@mail.ru"
# !git config --global user.password "1234qwerty"

# %%
token = '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'
username = 'Do0mblade'
repo = 'darknet-users'

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/Do0mblade/darknet-users.git
# Out:
# Cloning into 'darknet-users'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 150 (delta 8), reused 8 (delta 8), pack-reused 133
# Receiving objects: 100% (150/150), 59.27 KiB | 2.47 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
# !mv conspects_OreshkinEM.ipynb darknet-users/

# %%
cd /content/drive/MyDrive/Colab Notebooks/darknet-users
# Out:
# /content/drive/MyDrive/Colab Notebooks/darknet-users

# %% [markdown]
# # Математика Python
#
# * Какие математические операции можно проводить с числами в Python?
# * Приведите примеры и найдите 3 отличия от классической математики. Используйте ячейки кода и текста в Google Colab

# %% [markdown]
# Все математические операции:
#
#
# *   Сложение
# *   Вычитание
# *   Умножение
# *   Возведение в степень
# *   Деление
# *   Целочисленное деление
# *   Остаток от деления

# %%
10+5
# Out:
# 15

# %%
10-5
# Out:
# 5

# %%
10*5
# Out:
# 50

# %%
10**2
# Out:
# 100

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
10%5
# Out:
# 0

# %% [markdown]
# 1.   При обычном делении в ответе выводится не целове число, а вещественное.

# %%
10/2
# Out:
# 5.0

# %% [markdown]
# 2.   Есть вещественный ноль

# %%
k = 0.0
print(k)
print(k + 2)
# Out:
# 0.0
# 2.0

# %% [markdown]
# # Передача файла в репозиторий

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   conspects_OreshkinEM.ipynb

# %%
! git commit -m "Добавил файл conspects_OreshkinEM"
# Out:
# [master d97ea0b] Добавил файл conspects_OreshkinEM
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
token = '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'
username = 'Do0mblade'
repo = 'darknet-users'

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/Do0mblade/darknet-users.git (fetch)
# origin	https://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@github.com/Do0mblade/darknet-users.git (push)

# %%
# !git push origin OreshkinEM
# Out:
# error: src refspec OreshkinEM does not match any
# error: failed to push some refs to 'https://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@github.com/Do0mblade/darknet-users.git'
