# %% [markdown]
# #Настройка Git
# *   настроим ник и email
# *   получить токен github

# %%
# !git config --global user.name "OreshkinEM"
# !git config --global user.email "oreshkine04@mail.ru"

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/Do0mblade/darknet-users.git
# Out:
# Cloning into 'darknet-users'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 150 (delta 8), reused 8 (delta 8), pack-reused 133
# Receiving objects: 100% (150/150), 59.27 KiB | 2.47 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
# !mv conspects_OreshkinEM.ipynb darknet-users/

# %%
cd /content/drive/MyDrive/Colab Notebooks/darknet-users
# Out:
# /content/drive/MyDrive/Colab Notebooks/darknet-users

# %% [markdown]
# # Математика Python
#
# * Какие математические операции можно проводить с числами в Python?
# * Приведите примеры и найдите 3 отличия от классической математики. Используйте ячейки кода и текста в Google Colab

# %% [markdown]
# Все математические операции:
#
#
# *   Сложение
# *   Вычитание
# *   Умножение
# *   Возведение в степень
# *   Деление
# *   Целочисленное деление
# *   Остаток от деления

# %%
10+5
# Out:
# 15

# %%
10-5
# Out:
# 5

# %%
10*5
# Out:
# 50

# %%
10**2
# Out:
# 100

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
10%5
# Out:
# 0

# %% [markdown]
# 1.   При обычном делении в ответе выводится не целове число, а вещественное.

# %%
10/2
# Out:
# 5.0

# %% [markdown]
# 2.   Есть вещественный ноль

# %%
k = 0.0
print(k)
print(k + 2)
# Out:
# 0.0
# 2.0

# %% [markdown]
# # Зона для коммитов

# %%
# !git status
# Out:
# On branch oreshkin
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   conspects_OreshkinEM.ipynb

# %%
# !git add .

# %%
# !git status
# Out:
# On branch oreshkin
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   conspects_OreshkinEM.ipynb

# %%
# !git config --global user.name "OreshkinEM"
# !git config --global user.email "oreshkine04@mail.ru"

# %%
! git commit -m "Добавил ветку oreshkin"
# Out:
# [master fdb7f9a] Добавил раздел log
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite conspects_OreshkinEM.ipynb (98%)

# %%
token = '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'
username = 'Do0mblade'
repo = 'darknet-users'

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/Do0mblade/darknet-users.git (fetch)
# origin	https://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@github.com/Do0mblade/darknet-users.git (push)

# %%
# !git push origin oreshkin
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 3.96 KiB | 675.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/Do0mblade/darknet-users.git
#    f5b8659..fdb7f9a  master -> master

# %%
# !git pull origin oreshkin
# Out:
# From https://github.com/Do0mblade/darknet-users
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# # Журнал коммитов - log

# %%
# !git log
# Out:
# commit f5b865915fb0c2fd1aa515ef7c8895ed6dba6104 (HEAD -> master, origin/master, origin/HEAD)
# Author: OreshkinEM <oreshkine04@mail.ru>
# Date:   Sat Apr 29 12:10:27 2023 +0000
#
#     Добавил файл conspects_OreshkinEM
#
# commit 53607060fbeea5b9286a266f6ddfbe98e74241a8
# Author: OreshkinEM <oreshkine04@mail.ru>
# Date:   Sat Apr 29 12:03:24 2023 +0000
#
#     Добавил файл conspects_OreshkinEM
#
# commit 510360d048053fe8cd4e0b80494e6bbec06ca509
# Author: OreshkinEM <oreshkine04@mail.ru>
# Date:   Sat Apr 29 12:02:06 2023 +0000
#
#     Добавил файл conspects_OreshkinEM
#
# commit 914a324961acb19f4aeb527be52596d42ea280d4
# Author: OreshkinEM <oreshkine04@mail.ru>
# Date:   Fri Apr 28 14:50:37 2023 +0000
#
#     Добавил файл conspects_OreshkinEM
#
# commit d9cd9abb96b6bb0ade7779a921bef755c8d5c084
# Author: OreshkinEM <oreshkine04@mail.ru>
# Date:   Fri Apr 28 14:43:39 2023 +0000
#
#     Добавил файл conspects_OreshkinEM
#
# commit d97ea0b82827b90703b3cab2d3181e7138afa668
# ...

# %%
# !git log --oneline
# Out:
# f5b8659 (HEAD -> master, origin/master, origin/HEAD) Добавил файл conspects_OreshkinEM
# 5360706 Добавил файл conspects_OreshkinEM
# 510360d Добавил файл conspects_OreshkinEM
# 914a324 Добавил файл conspects_OreshkinEM
# d9cd9ab Добавил файл conspects_OreshkinEM
# d97ea0b Добавил файл conspects_OreshkinEM
# fa559e0 Добавил файл conspects_OreshkinEM
# 271545a Подправил дз
# 20d599d Выложил командное задание
# 5023d2d Добавил дз для команды
# e857f22 Добавил замечания
# f6d2aac Изменил Smith на Brown
# 7a7173c Добавил файлы .gitignore, page_01, page_02
# 18f6793 Добавила раздел log
# 75c7ba5 Добавила раздел log
# aaec0d6 Добавила списковое включение
# 0d71be2 Добавила списковое включение
# 8cd386a Добпвила свой новый файл в репозиторий
# 2b15f9f Добавил раздел log
# f08b938 Добавил раздел log
# 71c7123 Сделал дз
# 85436b2 Сделал дз
# f91e454 Изменил дз
# 18137dc Изменил дз
# d5ef1e4 Изменил дз
# aacc5ca Добавил дз
# 328c861 Добавил изменения ф свой файл
# ...

# %% [markdown]
# #Ветвление в Git

# %%
# !git branch
# Out:
#   master
# * oreshkin

# %%
# !git checkout -b oreshkin
# Out:
# Switched to a new branch 'oreshkin'
